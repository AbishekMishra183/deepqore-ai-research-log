# %% [markdown]
# # Opp
# - Generality to specilality
# - Feature of OOP
#   1. python ma haryak cig chai object ho (object chai kunai class kai huna sakxa
#   2. Class
#      => class is a blueprint
#      ![image.png](attachment:de48392e-8475-4581-8b4b-2257e2426258.png)
#
#      ![image.png](attachment:dd677c95-c615-420e-a9e4-00ebb237ff3d.png)

# %% [markdown]
# # Jastai real world ma herne ho vanye everything around us in an object but the main point to which class that is associated it is different
# - if i consider myself as an object then the main important point is to which class i am associated with just say for example i am associated with class person
# - if you see any object around you the main important point is to which things it is associated with
# - object like(ram, hari, laptop,bus , etc everything)
# - class is found by the collection of the different object
# - in the oop every variable is treated as object a=2 here a is an object

# %% [markdown]
#  # python ma diffeent datatypes jastai list , tuple  xa rw tini datatype banauno ko kei na kei ta matlab hola ni ta   rw banauno ko  karan k ho vanye datatypes define the class or blueprint of that thing
#  example jastai ma kunai list banaudai xau vanye
#  L=[1,2,3,4,5]
#  if i  write L. and  if i press shift +tab then i find different function rw tini function testo function hun jun list object ley matrw use garna paunxa
#
#  => point to remember in python
#  - datatype is class
#  -rw jun datatype ko lagi maile variable banaye teslai object vanainxa
# => class banauna is more difficult rather than creating the object kinavanye class banauda yakdam dherai function or the blue print banuno parxa tei vayrw
#
#
# ![image.png](attachment:108cde0d-2a6e-4fa7-b7d9-126b2bf9d228.png)

# %%
L=[1,2,3,5,]
L.append

# %%
a=2
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # class ko name banauda everycase should be in pascal case
# # pascal case is ThisIsPascalCase(every  first letter should be capital)
# # function name should be in snake case (name_name  example avarage_value)
# ![image.png](attachment:5170b4bb-1f69-4b5e-9e96-ee62506e6446.png)

# %% [markdown]
# # syntax to make the object:
# object_name=class_name()

# %% [markdown]
# # example : we are going to make a software for an atm machine
# - it must be written in the oop(class and object type)
# - the idea behind this is one customer, (yauta customer atm machine ma gayrw jasari behave garxa usko representation huno paryo class banayrw )
# - just imagine what are the data ,attributes  of that class (customer atm ma gayrw k k data use garxa , kasto kasto attributes use garxa)
# - data chai (balance, atm pin)
# - attribute(deposit, withdraw, checkbalance)
# - class banauda camel case(vannoko matlab first letter capital)

# %% [markdown]
# # tespacchi main bujne kura function vs Method
# => Function vs Methods
#  1st difference
# - hami lai tha xa function vanyako k ho vanyrw tei kunai function banauno normally (normal function)
# - Method is also a special  function but it is written inside a class
#
# 2nd difference: how they are called to use them
#
# -jastai hami ley len(L) garda yesko output chai length of the L ayunxa rw yo actually a function
#
# - jastai L.append(1) so here append() is a function but see how append is called vanno ko matlab append function use garna lai we need dot aghadi so yeslai chai method vaninxa
# - L.append(1)=> it is the function defined inside list class
#
#   3rd difference :
#   -Function can be accessed by everyone but method can be accessed by the object inside that class

# %% [markdown]
# # Always remember:
# yadi hami class vo vitrw variable banaudai xaum  vanye  tesali hami jailey pani  special method vitrw banauno parxa  jaslai  hami def __init__()  vanxau
#
# def __init__(self):
# =>yo method ko input ma always self hunccha
#
#
#     => Teso vaye self kina  hunccha ta  self ko actual meaning k ho
#     Lets handle this step by step

# %% [markdown]
# # first know what is init in the above method
# - so mathi jun __init__ xa yo chai yauta constructor ho then comes in mind , what is constructor
# - constructure=>magic/dunder/special methods
# - constructor=> it is a special method jasko vitrw rakhyako code automatically execute hunccha  when we make the object of that class ,(there is no requirement of calling that method)
#
# - when constructor is used ?
#   1.constructor ko vitrw hami configuration related task garna khojxau jo user key upar nhai xodna chayanga
#   example
#   yadi maile kunai app chalauno xa vanye tesko lagi internt chayinxa teo app use garna rw maile app kholye ani app bata button press garye to on  the internet this is a bit weired in that case

# %% [markdown]
# # lets discuss about self
# - kunai pani class ma 2 ota kura hunxan (data, methods)
# - teo data rw method lai access class ko object matrw garna sakxa
# - sometimes, malai yautai class ko method method bich pani comminucate garno parne huna sakxa
# -self is just like a object in python
# - if self is an object then kunai na kunai thau ma store hunccha
# - store huno matlab self ko (id,address)hunccha
# - if i want to print the id or self then
# - print(id(self))    then                     it helps to know about
# - print(id(object))
#
# class AtM ko
# example ma atm1 is an  1st object
# atm=Atm()
# print(id(self))
# print(id(atm1))
# atm1=self=214761457
# then at this time id of atm1 and id of self is same(1214761457)
#
# again if i make the atm2 is an 2nd object of class Atm
# then
# print(id(self))
# print(id(atm2))
#
# then at this time id of atm2 and self at that time is same (127236753)
# self=atm2=127236753
#
# IN CONCLUSION
# so self vanayako chai k ho vanye jo pani object sanga ma currently kam gardai xau TEI NOII self ho
#
#
# tei vayrw maile harak method vitrw chai self dino parxa
# generally k hunccha vanye
# jati bela ma object banauxau
# example:
# object.method()=> yesari object banayrw call garda method vitrw object ko address pass vairako hunccha  object.method(object address)
#
# example:
# object2.method2(address of object2)
# object1.method1(address of object1)
# by default yasto hunccha
#
# if hami ley object vitrw 2 ota parameter pathye vaye pani by default 3 ota parameter pass vako hunccha
#
# s1.sum(2,3)==== yesari pathye vanye backend ma chai  yasto hunccha
#
# s1.sum( address of s1,2,3) store hunccha rw yei kura pass hunccha
#
#
#
# ---------------------------------------------
# why we need the concept of self
# => kunai pani class vitrw 2 ota method xan vanye tei 1 otai class vitrw vayako method ley tei class ma vayako arko method lai call garna sakdaina
# teslai call garna we need object everytime ma kunai function or data use garda teo aafai as a self aayrw call garidinxa

# %%
class Atm:

    def __init__(self):
        self.pin = ""
        self.balance = 0
        print(id(self))
        self.menu()

    def menu(self):
        user_input = input(""" 
        Hello, how would you like to proceed?
        1. Enter 1 to create pin
        2. Enter 2 to deposit
        3. Enter 3 to withdraw
        4. Enter 4 to check balance
        5. Enter 5 to exit
        """)

        if user_input == '1':    
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3': 
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        elif user_input == '5':
            print("bye")
        else:
            print("Invalid choice")

    def create_pin(self):
        self.pin = input("Enter your new pin: ")
        print("Pin set successfully")

    def deposit(self):
        temp = input("Enter your pin: ")
        if temp == self.pin:
            amount = int(input("Enter the amount: "))
            self.balance = self.balance + amount
            print("Deposit successful")
        else: 
            print("Invalid pin")

    def withdraw(self):
        temp = input("Enter your pin: ")
        if temp == self.pin:
            amount = int(input("Enter your amount: "))
            if amount <= self.balance:
                self.balance = self.balance - amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_balance(self):          
        temp = input("Enter your pin: ")    
        if temp == self.pin:
            print("Your balance is:", self.balance)
        else:
            print("Invalid pin")


# Run the program
atm = Atm()
atm.balance
print(id(atm))
print(id(self))
# Out:
# 2447877051776
#
#         Hello, how would you like to proceed?
#         1. Enter 1 to create pin
#         2. Enter 2 to deposit
#         3. Enter 3 to withdraw
#         4. Enter 4 to check balance
#         5. Enter 5 to exit
#          5
# bye
# 2447877051776
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 68
#      66 atm = Atm()
#      67 print(id(atm))
# ---> 68 print(id(self))
#
# NameError: name 'self' is not defined

# %%
# lets create our own datatype 
#Fraction
class Fraction:
    def __init__(self,n,d):
        self.n=n
        self.d=d

# %% [markdown]
# # Encaptulation
#    ### what is instance variable?
#    -instance varibale vanyako testo value haru jaslai hami constructor vitrw banaunxau
#    example:
#    def __init__(self):
#    self.pin=pin
#    sel.balance=0
#
#    yei haru chai instance variable hun
#
# => instance variable kina vaninxa vanye yo variable ko value farak farak hunccha harak object of the class ko lagi
#
#
# # now lets discuss encapsulation
# -class ko data member lai pubic narakhne
# - class vitrw ta data rw methods 2 otai hunxan rw teo 2 otai data rw method lai class ko object ley access garana sakxaa
# - at that time if any object ko help ley data change ni garna sakaxa by providing any value, the solution will be i can hide this  data section code
# - to hide that section i can do something like this
# -  def __init__(self):
#    self.__pin=pin  # double underscore
#    sel.__balance=0
#
#
#    aba yaslai pani acess ta garna milxa hide or access garna nasakye data or method lai
#    if class name is Atm and i want to access self.__pin=pin
#
#    internally python  yeslai store garna self.__pin=pin
#
#    -className__Pin=>_Atm__pin   garyaum vanye we can access this so that
#
#
#
#    # NOthing in python is truly private
#
#    - so yei mathi ko case ma hami , get_pin(getter) rw set_pin(setter) vanne method banauna sakxan so that it wont crash , kasri handle garyo ta yasle crash huna bata vanda method can be control, methods ta hamile banaune ho so rul e hamro noii hunccha

# %%
# hiding data members for accessing using  (__ 'double underscope') to visulaize clearly see the difference in this and above program 

class Atm:

    def __init__(self):
        self.__pin = ""
        self.__balance = 0
        print(id(self))
        self.menu()
    def get_pin(self):
        return self.__pin

    def set_pin(self,new_pin):  # ho yo chai  data ko lagi method ho kunai kam garno paryo data ma vanye we go through this method 
        # aba method lai afno rule ko hisab ley set garna milxa (two methods for every data setter, getter)
        if type(new_pin)==str:
            self.__pin==new_pin
            print("pin changed")
        else:
            print("not allowed")
    def menu(self):
        user_input = input(""" 
        Hello, how would you like to proceed?
        1. Enter 1 to create pin
        2. Enter 2 to deposit
        3. Enter 3 to withdraw
        4. Enter 4 to check balance
        5. Enter 5 to exit
        """)

        if user_input == '1':    
            self.create_pin()
        elif user_input == '2':
            self.deposit()
        elif user_input == '3': 
            self.withdraw()
        elif user_input == '4':
            self.check_balance()
        elif user_input == '5':
            print("bye")
        else:
            print("Invalid choice")

    def create_pin(self):
        self.__pin = input("Enter your new pin: ")
        print("Pin set successfully")

    def deposit(self):
        temp = input("Enter your pin: ")
        if temp == self.__pin:
            amount = int(input("Enter the amount: "))
            self.balance = self.__balance + amount
            print("Deposit successful")
        else: 
            print("Invalid pin")

    def withdraw(self):
        temp = input("Enter your pin: ")
        if temp == self.__pin:
            amount = int(input("Enter your amount: "))
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("Operation successful")
            else:
                print("Insufficient funds")
        else:
            print("Invalid pin")

    def check_balance(self):          
        temp = input("Enter your pin: ")    
        if temp == self.__pin:
            print("Your balance is:", self.__balance)
        else:
            print("Invalid pin")


# Run the program
atm = Atm()
atm.          # yo garyrw tab garda we cannot access the data check this after using __
print(id(atm))
print(id(self))
# Out:
# 2598049952864
#
#         Hello, how would you like to proceed?
#         1. Enter 1 to create pin
#         2. Enter 2 to deposit
#         3. Enter 3 to withdraw
#         4. Enter 4 to check balance
#         5. Enter 5 to exit
#          1
# Enter your new pin:  12
# Pin set successfully
# 2598049952864
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 68
#      66 atm = Atm()
#      67 print(id(atm))
# ---> 68 print(id(self))
#
# NameError: name 'self' is not defined

# %%
# Reference Variable
- object banaune bela hami object lai jun variable ma store garxau tei variable lai reference variable vaninxa 
object=className()  # here object is the reference of that address of actual object derieved from the class

# %%
class Customer:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

def greet(customer):
    if customer.gender=='male':
          print("Hello", customer.name,"sir")
    else:
        print("Hello", customer.name,"mam")
    
    
cust=Customer("Abishek","male") 
greet(cust)  # yesma hami object lai as a parameter pass gardai xaum 
# greet function is outside the class rw teo vitrw ko data lai access garna tei class ko object ley garxa so that 
# hami ley object lai pass garyako ho
# Out:
# Hello Abishek sir

# %% [markdown]
# # in python, class ko object are mutable like lists, dict, and sets
# - Instance variable are always under constructor
# - Static variable are starting or outside of the constructor
# - these two figure makes clear
#
# ![image.png](attachment:d991bdf2-ac99-4948-8115-353da10d83a8.png)
#
# 2nd figure:
#
# ![image.png](attachment:0803a068-651c-471a-8c90-1f68056feee0.png)

# %% [markdown]
# # Relationship in python
# Aggregation- Has a relationship
# Inheritance- Is a relationship
# ![image.png](attachment:da016ff9-42aa-45cc-92be-cbb6f22e9b4b.png)

# %%
# inheritance:
class User:
    def login(self):
        print("login")
    def register(self):
         print("Register")
         
class Student(User):    # here student(user)=> it means student class can use all the methods or data of class user
    
    def enroll(self):
        print("Enroll")
    def review(self):
            print("review")

stu1=Student()
stu1.enroll()
stu1.review()
stu1.login()
stu1.register()
# Out:
# Enroll
# review
# login
# Register

# %%
# method overriding => having same method name in the different class 
# if there is child constructor then parent constructor is not called but if there is no child constructor parent constructor is called

# %% [markdown]
# # super keyword in inheritance
# it is used to inherit the parnet method (mostly used in overriding )
# if the name of the methods in the parent and children is same in that case
# example:
# Class Parent :
#     def buy():
#         pass
# class Child:
#     def buy()
#
# ![image.png](attachment:f578157f-27b9-418d-a9a9-4812366e9790.png)
#
# - Super keyword bata 2 0ta kura access garna sakinxa
#       1.parent method
#       2. parent constructor
#       3. cannot access Parent attribute
#
#   # super lai call garda kunai pani constructor super should be a first stmt

# %% [markdown]
# # Dcorators in python
# => Decorators is the function that takes another function as an argument and returns the function
#
# example or synatax:
# def decorator (fun): # this is compulasory
#     def wrapped():   # name of the function in the decorator name can be anything  aba yesma actual function ta hunccha but                                              also yesma extra kura wrapped garyako hunccha
# print("Transication initiated") # this is actually dectorator it is not program logic but it decorate(sajauno) the orginal function
# fun()   # actual function ko logic is here
# print("Transication success")   # this is also same as above
#
# return wrapper # point to remember decorator function returns the wrapper fuction=> so it returns the function(basically, not any values or anything)
#
# def hello():
# print(".........Executing all steps of transaction......')
# Hello1=decorator(hello)
# hello1()
#
#
#
#
#
#
# 🔹 Why Use Decorators?
#
# Logging
#
# Authentication
#
# Performance measurement (execution time)
#
# Access control
#
# Caching results

# %%
def my_decorator(func):
    def wrapper():
        print("Before the function runs")
        func()
        print("After the function runs")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()
#Here, @my_decorator is just a shortcut for writing:
#say_hello = my_decorator(say_hello)
# Out:
# Before the function runs
# Hello!
# After the function runs
