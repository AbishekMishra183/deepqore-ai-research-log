# %%
a=input("enter your first name ")
b=input("enter you second name")
# Out:
# enter your first name  Abishek
# enter you second name Mishra

# %%
a=input("enter your first name ")
b=input("enter you second name")
print(a,b,sep="-")
# Out:
# enter your first name  Abishek
# enter you second name Mishra
# Abishek-Mishra

# %%
a=float(input("enter any number"))
b=int(input("enter other number"))
sum=a+b
print(sum)
# Out:
# enter any number 12.5
# enter other number 13
# 25.5

# %%
type(a)
# Out:
# float

# %%
email = input("Enter your email: ")

if '@' in email:
    password = input("Enter your password: ")

    if email == "abishekmishra@gmail.com" and password == "abi123":
        print("Welcome")
    
    elif email == "abishekmishra@gmail.com" and password != "abi123":
        print("Please check your password again")

        password = input("Enter your password again: ")
        if password == "abi123":
            print("Finally correct password")
        else:
            print("Still incorrect")
    
    else:
        print("Incorrect credentials")

else:
    print("Invalid email")
# Out:
# Enter your email:  abishek mishra
# Invalid email

# %%
#indentation

# %%
name='xyz'
if name =='xyz':
    print(name)
# Out:
# xyz

# %% [markdown]
# # while loop in python
# => where to use the loops in the real world
#     -website ma chai product display garauna lai use hunccha loop
#     instead of making muntiple container for the individual
#     product make it as 1 container and loop that container

# %% [markdown]
# # syntax of while loop
# while condition:
#     code

# %% [markdown]
# # game challangle
# => this is basically the guessing  game

# %%
# to use the random number selection there is the module in python 
name as random 

to see how the syntax of the inbuid function
click shif and tab inside the brackeet 
example
random.randint(sift+tab)=> it displays the syntax of the randint

# %%
import random

# %%
random.randint(1,100)
# Out:
# 60

# %%
jackport=random.randint(1,100)
guess=int(input("guess any number"))
counter=1
while jackport!=guess:
    if guess<jackport:
        print("guess higher")
    else:
        print("guess lower")
    guess=int(input("guess any number"))
    
    counter=counter+1
print("this is the correct guess")
print (counter)
# Out:
# guess any number 88
# guess lower
# guess any number 56
# guess higher
# guess any number 58
# guess higher
# guess any number 59
# guess higher
# guess any number 60
# guess higher
# guess any number 63
# guess higher
# guess any number 67
# guess higher
# guess any number 69
# guess higher
# guess any number 73
# guess higher
# guess any number 88
# guess lower
# guess any number 83
# guess higher
# guess any number 84
# guess higher
# guess any number 86
# this is the correct guess

# %%
# for loop
for i in range(1,10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
for i in "kolkata":
    print(i)
# Out:
# k
# o
# l
# k
# a
# t
# a

# %%
for i in [1,3,4,5]:
    print(i)
# Out:
# 1
# 3
# 4
# 5

# %%
# when to use the for loop and when to use the while loop
for loop=> when you know that how many times the loop is being executerd
while=> when you dont know

# %%
# Nested loops in python

# %%
# *
# **
# ***
# ****
# *****
rows=int(input("enter how many rows"))
for i in range(1,rows+1):
    for j in range(0,i):
        print("*" ,end="")  # j ko value rowise print garna ko lagi end use garyako
    print("")    # tespacchi the arko iteration ma ta loop change garno paryo ni ta teivayrw

# %%
printing the opposite form
*
**
***
****
*****

# %%
rows=int(input("enter how many rows"))
for i in range(rows,1,-1):
    for j in range(i,1,-1):
        print("*",end="")
    print("")
# Out:
# enter how many rows 10
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %%
this above thing can be visulaize using the python visualize 
which can be found by searching in the chrome

# %%
there are many of the build in python functions 
some of the python bulid in functuion are:
-sum
-abs
-min/max
-pow(2,4)
round()

# %% [markdown]
# There are buid in modules in the python
#     aru language ma chai module lai library vaninnxa
# # What are modules ?
# => conisder the module to be same as the code library
# => A file containing a set of the functions you want to include
# in your application
#  Examples of the python  modules:
# - math
# -rand0m
# -os
# -time

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\Acer\anaconda3\envs\venv\lib\pkgutil.py:92: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(info.name)
# C:\Users\Acer\anaconda3\envs\venv\lib\site-packages\_distutils_hack\__init__.py:31: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# IPython             cachetools          mimetypes           stringprep
# PIL                 calendar            mmap                struct
# __future__          catboost            mmapfile            subprocess
# _abc                certifi             mmsystem            sunau
# _ast                cgi                 modulefinder        symbol
# ...

# %%
import math

# %%
 # math. (import math garyesakye pacchi math dot tespaccchi k k operation garna sakinxa
-math use garyrw dekhinxa sabbai (dot pacchi tab press garne)

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(5)
# Out:
# 120

# %%
import random

# %%
random.randint(1,4)
# Out:
# 1

# %%
import time

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=9, tm_mday=14, tm_hour=12, tm_min=6, tm_sec=36, tm_wday=6, tm_yday=257, tm_isdst=0)

# %%
time.ctime()
# Out:
# 'Sun Sep 14 12:07:30 2025'

# %%
import os

# %%
os.getcwdb()   # this getcwdb is used to see the current working directiory
# Out:
# b'C:\\Users\\Acer\\OneDrive\\Desktop\\New folder'

# %%
# strings in the python

=> in python specifically , strings are the sequence of unicode characters 
-creating strings
-Accessing strings
-Adding charts to strings
- Editing strings
-deleting strings 
-operation on strings 
- string function

# %%
c='hello'
print(c)
# Out:
# hello

# %%
# Accessing the substrings from the string 
- concept of indexing

# %%
# indexing
c="hello"
print(c)
# Out:
# hello

# %%
for i in c:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %%
print(c[2])    # positive indexing
# Out:
# l

# %%
# types of the indexing
- positive indexing 
-negative indexing

# %%
print(c[-1])   # negative indexing
# Out:
# o

# %%
# slicing 
=> it provides the range between any two numbers say[a,b]

# %%
# slicing 
c="Hello wORLD"
print(c)
# Out:
# Hello wORLD

# %%
print(c[0:5])
# Out:
# Hello

# %%
print(c[2:])
# Out:
# llo wORLD

# %%
print(c[:5])
# Out:
# Hello

# %%
print(c[:-1])
# Out:
# Hello wORL

# %%
print(c[-1:])
# Out:
# D

# %%
print(c[-10:])
# Out:
# ello wORLD

# %%
# note: if you are working with the positive indexing then step also must be positive

# %%
print(c[::-1])   # reversing the string
# Out:
# DLROw olleH

# %%
print(c[-1:-12:-1])
# Out:
# DLROw olleH

# %%
# Editing and deleting the strings 
c="Abishek"
# if i want to edit "A" from the Abishek using this 
c[0]='x'   # this shows the error
# reason k ho vanda strings are the immutable Data Type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       2 c="Abishek"
#       3 # if i want to edit "A" from the Abishek using this
# ----> 4 c[0]='x'   # this shows the error
#
# TypeError: 'str' object does not support item assignment

# %%
There is no edithing in the strings cause you cannot edit the string 
once it is declared or defined but support reassignment 

so once  string is defined then cannot add the character in the existing one , cannot replace the character of the string  Also cannot delete the individual character
from the string

# %% [markdown]
# # List in the python
# - what is list
# - list vs Array
# - Creating the list
# - Accessing the list
# - Editing the list
# - Adding the list
# - Deleting the list
# - Some operations in the list
# - Functions in the list

# %%
# list is the data type which is used to store the muntiple objects 
- in the list there is no compulsory that items are stored continuoulsy
- but  in the case of the arry the items are stored continuously so 
it is considered to be faster than the list

# %% [markdown]
# ![image.png](attachment:7f10aa9e-4c67-4e66-8414-5ee7bc7715a2.png)

# %%
 # to create the empty list
arr=[]
print(arr)
# Out:
# []

# %%
arr=[1,3,4,5]
print(arr)
# Out:
# [1, 3, 4, 5]

# %%
arr=[1,'Ram',2.5]
print(arr)
# Out:
# [1, 'Ram', 2.5]

# %%
# how to create the multidimensional list 
# 2D list - list vitrw list banaune 
arr=[1,2,3,4,[2,3]]  # this is hetrogenous that is muntiple data type can be strore 
# in the single list 
- in the above example arr there is 1 ,2 , 3,4 , as a integer and 
also threre is list inside the list after integer so multidimensional

# %%
# for the 3D list => list  vitrw -list vitrw- list banaune 
arr=[1,2,3,[1,2,4,[1,2,3,4]]]
print(arr)
# Out:
# [1, 2, 3, [1, 2, 4, [1, 2, 3, 4]]]

# %%
# how to access the items from the list 
arr[1]
# Out:
# 2

# %%
arr[3] # this gives the whole index value at the list which is in 3rd
# Out:
# [1, 2, 4, [1, 2, 3, 4]]

# %%
arr[3:1]
# Out:
# []

# %%
arr[3][1] # this is used to access the element from the 2 D array
# this generally gives the index value of the 2nd list 1 th index item
# Out:
# 2

# %%
# how to edit the items from the list 

list in the python are mutable 

suppose we have a list L=[1,3,4,5] we we want to edit the first 
index  with L[0]=100 it actually works

# %%
L=[1,2,3,5]
print(L)
L[0]=100
print(L)
# Out:
# [1, 2, 3, 5]
# [100, 2, 3, 5]

# %% [markdown]
# # we can also do the negative indexing , Sclicing in the list

# %%
L=[1,2,3,5]
print(L)
L[-2]=100   # see the result in this 
print(L)

# %%
# Slicing
L=[1,2,3,5]
print(L)
L[1:3]=[100,200]   # this is sclicing in the list 

print(L)
# Out:
# [1, 2, 3, 5]
# [1, 100, 200, 5]

# %% [markdown]
# # How to add the new items in the list , Three ways t0 add the element
# - append
# -extend
# -insert

# %%
# if i want to add the element in the last then Append is used 
L.append(1000)
print(L)  # there is 3 times 1000 because this is run 3 times so 3 times is add
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000]

# %%
# if  we want to muntiple item to add in the last then we use the Extend
# lets say i want to add[5000, 6000, 7000]
print(L)
L.extend([5000,6000,7000])  # yauta vanda dherai xa vanye list banune 
print(L)
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000]
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000]

# %%
# simple difference between the append and extend see the output
print(L)
L.append([5,6])
print(L)
# in this case if i run this this will add the whole list [5,6] into the 
# existing list at a time
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6]]
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6]]

# %%
# Append function=> whole things is added at a time 
print(L)
L.append([5,6])
print(L)
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6]]
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6], [5, 6]]

# %% [markdown]
# # Now see the difference in the extend
# => in the extend part it breaks down the list or the content in the smaller part and add one by one
# this means if i want to add [5, 6 ] then it first add 5 and then 6 one by one

# %%
print(L)
L.extend([5,6])
print(L)
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6], [5, 6]]
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6], [5, 6], 5, 6]

# %%
# in the above output see how 5 and 6 are printed

# %% [markdown]
# # now another method to add the items is
# ---------insert method----------------------------
# =>this is used to add the elements in the list at the desiered position
#
# if i want to add hello world at between 100 and 200 of the above list then
# Syntax is: Object.insert(position, what you want to print)

# %%
print(L)
L.insert(2,"Hello world")
print(L)
# Out:
# [1, 100, 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6], [5, 6], 5, 6]
# [1, 100, 'Hello world', 200, 5, 1000, 1000, 1000, 5000, 6000, 7000, [5, 6], [5, 6], [5, 6], [5, 6], 5, 6]

# %% [markdown]
# # How to delete the elements from the list(4 ways)
# -del=> delete the entire list
# -remove
# -pop
# -clear

# %%
del L

# %%
L # since it is deleted so there is No L presence there
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 L
#
# NameError: name 'L' is not defined

# %%
L1=[1,2,"Hello", 2.4]
print(L1)
# Out:
# [1, 2, 'Hello', 2.4]

# %%
print(L1)
del L1[2]  # second item is deleted 
print(L1)
# Out:
# [1, 2, 2.4]
# [1, 2]

# %%
# remove => it is used when we dont know the index of the item but we know that this element exist in the list at that time remove is used 
L1.remove(2)

# %%
print(L1)
# Out:
# [1]

# %%
# pop =>this is used to delete the list element of the list 
L1.pop()
print(L1)
# Out:
# []

# %%
# Clear => it doesnot delete your list insted it makes the list empty

# %%
# Functions in the list 

L=[1,2,4,5,6]
print(len(L))
# Out:
# 5

# %%
# min function in the list

# %%
# program:
L1=[1,1,2,2,3,3,4,4] # remove all the duplicate values from the list 
L=[]
for i in L1:
    if i not in L:
        L.append(i)
print(L)
# Out:
# [1, 2, 3, 4]
