# %% [markdown]
# # to make the function in the python
# -Syntax
# def function_name():

# %%
def is_even(number):
    if type(number)==int:
        if number%2==0:
            return 'Even number'
        else: 
            return 'odd number'
    else:
        return 'not allowed'
is_even('hello')
# Out:
# 'not allowed'

# %% [markdown]
# # Parameter and Argument on pyhon
# -A parameter is like a placeholder or a variable name that we write inside the function definition.
# -An argument is the actual value we pass into the function when calling it.
# Parameter = empty box with a label ("name").
#
# Argument = actual thing you put in the box ("Abishek").

# %% [markdown]
# # Arguments
# 1.default Argument
# 2. Positional Argument => inorder ma
# 3. Keyword Argument
# 4.Arbitrary Argument

# %%
def power(a,b):
    return a**b
power(3,2)
# Out:
# 9

# %%
# Lamda function => these are the function which have no name (

# %%
# jastai manau hami lai square nikalno parne xa kunai number ko teo bela 
y = lambda x: x**2
print(y(5))   # ✅ correct
# Out:
# 25

# %%
print(x=(5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(x=(5))
#
# TypeError: 'x' is an invalid keyword argument for print()

# %%
a=lambda x,y:x+y
print(a(2,3))
print(type(a))
# Out:
# 5
# <class 'function'>

# %% [markdown]
# # Difference between other function and other function
# 1.lambda has no return value as it return the function itself
# 2. There is only one line  function
# 3. it cannot be used more and again , no code reusuablity (can be used only at a time)
# 4. Lambda function has no name
#
# # Why Lambda function is used
# - Along with higher order function
# => higher order function are the function yadi ma kunai function use gardai xau vanye teo function use garna ko lagi malai arko function chyinxa  or yaslai k vaninxa vanye yasto function jasko return garda feri yauta function return garxa

# %%
# lets say ma kunai yauta string vitrw ko first letter A xa ki noii vanyrw check garno xa then
b=lambda x:x[0]=='a'
print(b('abishek'))
print(b('banana'))
# Out:
# True
# False

# %%
# to find the given number is odd or not using lambda finction
o=lambda num:'odd ' if num%2!=0 else 'even'
print(o(5))
print(o(6))
# Out:
# odd
# even

# %% [markdown]
# # Higher order function
# L=[11,14,21,23,56,78,45,29,28]
# now, from  the above list i had to find 3 outputs
# 1. i need sum of all the even numbers from the list
# 2. i need the sum of odd numbers from the list
# 3. i need sum of all the number which are divisible by 3
#    -in this type of program

# %%
def return_sum(fun,L):
    result=0

    for i in L:
        if fun(i):
            result=result+i
            
    return result
L=[11,14,21,23,56,78,45,29,28]

x=lambda x:x%2==0
y=lambda x:x%2!=0
z=lambda x:x%3==0
print(return_sum(x,L))
print(return_sum(y,L))
print(return_sum(z,L))
# Out:
# 176
# 129
# 144

# %%
#Map
# Filter 
# reduce

# %% [markdown]
# # map(map function are the function)
# syntax=>map(function(generally lambda, iterable(this can be list or anything))

# %%
# example of map 
L=[1,3,5,6,7,8]
map(lambda x:x*2,L) # this generally gives the addres to find the value after operation use list to conver it 
list(map(lambda x:x*2,L)) # list is used to convert it
# Out:
# [2, 6, 10, 12, 14, 16]

# %%
# to check every item is odd or even you have to do something like this
L=[1,3,5,6,7,8]
map(lambda x:'even' if x%2==0 else 'odd',L)
list(map(lambda x:'even' if x%2==0 else 'odd',L))
# Out:
# ['odd', 'odd', 'odd', 'even', 'odd', 'even']

# %% [markdown]
# # Filter
# => if i wnat a number greater than 4 from the list at that time

# %%
filter(lambda x:x>4,L) # this generally gives the address

# %%
list(filter(lambda x:x>4,L))
# Out:
# [5, 6, 7, 8]

# %%
fruits=['Apple','Mango','Gauva','Orange']
# i need the fruits which name contain e
list(filter(lambda fruits:'e' in fruits,fruits))
# Out:
# ['Apple', 'Orange']

# %% [markdown]
# ![image.png](attachment:c754ddf7-0f5c-434e-a2a2-290fb07ed106.png)

# %% [markdown]
# # Reduce
# - yo directly python vitrw hudaina so yaslai import garno parxa using funtools
# - yeslae khas ma list lai reduce garna lai use hunccha
# ![image.png](attachment:c2e2a350-cbd4-4a7e-84c3-fe111232f90f.png)

# %%
from functools import reduce
reduce(lambda x,y:x+y,[1,2,3,4])
# Out:
# 10

# %% [markdown]
# # List comprehension
# ![image.png](attachment:ecfd9d41-37bc-4fd9-b745-4a54069cbef7.png)

# %%
# List comprehension 
L1=[1,2,3,4,5,6] # to double this list we can use list comphernsion
L1=[item*2 for item in L1]
print(L1)
# Out:
# [2, 4, 6, 8, 10, 12]

# %% [markdown]
# # Dictionary comphrenssion
# ![image.png](attachment:b026c1df-7da3-4bbd-840f-88ff5454740b.png)

# %% [markdown]
# ![image.png](attachment:c748fd00-dbb4-4c78-bd6f-7e205c59484a.png)
